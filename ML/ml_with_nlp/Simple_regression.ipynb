# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('Salary_Data.csv', index_col=0) #importing dataset

# %%
data
# Out:
#                  Salary
# YearsExperience
# 1.6               40343
# 1.8               47205
# 2.0               38731
# 2.5               44525
# 2.6               46525
# 2.7               40891
# 3.0               42891
# 3.4               57642
# 3.5               61150
# 3.7               55445
# 3.7               65445
# 4.2               58189
# 4.4               64218
# 4.5               56794
# 4.6               58794
# 4.7               57957
# 4.8               58081
# 5.0               62111
# 5.2               64111
# 5.4               68938
# 5.6               67029
# 5.7               69029
# 5.8               84088
# 6.0               86088
# 6.4               82363
# 6.5               94940
# 7.3               92738
# 7.6               99273
# 8.4              102302
# 8.7              114812
# 9.2              110431
# 9.5              106582
# 10.0             117969
# 10.1             113635
# 10.8             123391
# 11.0             122872
# ...

# %%
for i, j in data.iterrows():
    print(i)
    print(j)
# Out:
# 1.6
# Salary    40343
# Name: 1.6, dtype: int64
# 1.8
# Salary    47205
# Name: 1.8, dtype: int64
# 2.0
# Salary    38731
# Name: 2.0, dtype: int64
# 2.5
# Salary    44525
# Name: 2.5, dtype: int64
# 2.6
# Salary    46525
# Name: 2.6, dtype: int64
# 2.7
# Salary    40891
# Name: 2.7, dtype: int64
# 3.0
# Salary    42891
# Name: 3.0, dtype: int64
# 3.4
# Salary    57642
# Name: 3.4, dtype: int64
# 3.5
# Salary    61150
# Name: 3.5, dtype: int64
# 3.7
# Salary    55445
# Name: 3.7, dtype: int64
# 3.7
# Salary    65445
# Name: 3.7, dtype: int64
# 4.2
# Salary    58189
# Name: 4.2, dtype: int64
# 4.4
# Salary    64218
# Name: 4.4, dtype: int64
# 4.5
# Salary    56794
# Name: 4.5, dtype: int64
# 4.6
# Salary    58794
# Name: 4.6, dtype: int64
# 4.7
# Salary    57957
# Name: 4.7, dtype: int64
# 4.8
# Salary    58081
# Name: 4.8, dtype: int64
# 5.0
# Salary    62111
# Name: 5.0, dtype: int64
# 5.2
# Salary    64111
# Name: 5.2, dtype: int64
# 5.4
# Salary    68938
# Name: 5.4, dtype: int64
# ...

# %%
df.head()
# Out:
#                    R&D Spend  Marketing Spend   Location     Profit
# Major&Minor Works
# 185849.20          151897.80        492284.10  Bangalore  217261.83
# 183097.70          166377.59        464398.53  Hyderabad  216792.06
# 173941.51          116145.55        428434.54       Pune  216050.39
# 164872.41          133671.85        403699.62  Bangalore  207901.99
# 162607.34          106391.77        386668.42       Pune  191187.94

# %%
df = pd.read_csv('50_companies.csv', index_col=0)
df

for i, j in df.iterrows():
    print(i)
    print(j)
    print("\n")
# Out:
# 185849.2
# R&D Spend           151897.8
# Marketing Spend     492284.1
# Location           Bangalore
# Profit             217261.83
# Name: 185849.2, dtype: object
#
#
# 183097.7
# R&D Spend          166377.59
# Marketing Spend    464398.53
# Location           Hyderabad
# Profit             216792.06
# Name: 183097.7, dtype: object
#
#
# 173941.51
# R&D Spend          116145.55
# Marketing Spend    428434.54
# Location                Pune
# Profit             216050.39
# Name: 173941.51, dtype: object
#
#
# 164872.41
# R&D Spend          133671.85
# Marketing Spend    403699.62
# Location           Bangalore
# Profit             207901.99
# Name: 164872.41, dtype: object
#
#
# 162607.34
# R&D Spend          106391.77
# Marketing Spend    386668.42
# Location                Pune
# Profit             191187.94
# Name: 162607.34, dtype: object
#
#
# 152376.9
# R&D Spend          114814.71
# Marketing Spend    383361.36
# Location           Bangalore
# Profit             181991.12
# ...

# %%
for lab, row in df.iterrows():
    # - Creating Seris on every iteration
    df.loc[lab, 'name_length'] = len(row["Location"])

# %%
df1 = df.copy()

# %%
df
# Out:
#                    R&D Spend  Marketing Spend   Location     Profit  \
# Major&Minor Works
# 185849.20          151897.80        492284.10  Bangalore  217261.83
# 183097.70          166377.59        464398.53  Hyderabad  216792.06
# 173941.51          116145.55        428434.54       Pune  216050.39
# 164872.41          133671.85        403699.62  Bangalore  207901.99
# 162607.34          106391.77        386668.42       Pune  191187.94
# 152376.90          114814.71        383361.36  Bangalore  181991.12
# 155115.46          162198.87        148216.82  Hyderabad  181122.51
# 150798.13          160530.06        344376.68       Pune  180752.60
# 141042.52          163718.95        332113.29  Bangalore  177211.77
# 143834.88          123679.17        325481.62  Hyderabad  174759.96
# 122413.08          125594.11        249660.95       Pune  171121.95
# 121171.96          106790.61        270244.55  Hyderabad  169259.40
# ...

# %%
df1['name_len'] = df1['Location'].apply(len) #It's either you use the loc or use the apply function

# %%
df1
# Out:
#                    R&D Spend  Marketing Spend   Location     Profit  name_len
# Major&Minor Works
# 185849.20          151897.80        492284.10  Bangalore  217261.83         9
# 183097.70          166377.59        464398.53  Hyderabad  216792.06         9
# 173941.51          116145.55        428434.54       Pune  216050.39         4
# 164872.41          133671.85        403699.62  Bangalore  207901.99         9
# 162607.34          106391.77        386668.42       Pune  191187.94         4
# 152376.90          114814.71        383361.36  Bangalore  181991.12         9
# 155115.46          162198.87        148216.82  Hyderabad  181122.51         9
# 150798.13          160530.06        344376.68       Pune  180752.60         4
# 141042.52          163718.95        332113.29  Bangalore  177211.77         9
# 143834.88          123679.17        325481.62  Hyderabad  174759.96         9
# 122413.08          125594.11        249660.95       Pune  171121.95         4
# ...

# %%
for lab, row in data.iterrows():
    print(str(lab) + ": " + str(row))
# Out:
# 1.6: Salary    40343
# Name: 1.6, dtype: int64
# 1.8: Salary    47205
# Name: 1.8, dtype: int64
# 2.0: Salary    38731
# Name: 2.0, dtype: int64
# 2.5: Salary    44525
# Name: 2.5, dtype: int64
# 2.6: Salary    46525
# Name: 2.6, dtype: int64
# 2.7: Salary    40891
# Name: 2.7, dtype: int64
# 3.0: Salary    42891
# Name: 3.0, dtype: int64
# 3.4: Salary    57642
# Name: 3.4, dtype: int64
# 3.5: Salary    61150
# Name: 3.5, dtype: int64
# 3.7: Salary    55445
# Name: 3.7, dtype: int64
# 3.7: Salary    65445
# Name: 3.7, dtype: int64
# 4.2: Salary    58189
# Name: 4.2, dtype: int64
# 4.4: Salary    64218
# Name: 4.4, dtype: int64
# 4.5: Salary    56794
# Name: 4.5, dtype: int64
# 4.6: Salary    58794
# Name: 4.6, dtype: int64
# 4.7: Salary    57957
# Name: 4.7, dtype: int64
# 4.8: Salary    58081
# Name: 4.8, dtype: int64
# 5.0: Salary    62111
# Name: 5.0, dtype: int64
# 5.2: Salary    64111
# Name: 5.2, dtype: int64
# 5.4: Salary    68938
# Name: 5.4, dtype: int64
# ...

# %%
data  #displaying the data
# Out:
#     YearsExperience  Salary
# 0               1.6   40343
# 1               1.8   47205
# 2               2.0   38731
# 3               2.5   44525
# 4               2.6   46525
# 5               2.7   40891
# 6               3.0   42891
# 7               3.4   57642
# 8               3.5   61150
# 9               3.7   55445
# 10              3.7   65445
# 11              4.2   58189
# 12              4.4   64218
# 13              4.5   56794
# 14              4.6   58794
# 15              4.7   57957
# 16              4.8   58081
# 17              5.0   62111
# 18              5.2   64111
# 19              5.4   68938
# 20              5.6   67029
# 21              5.7   69029
# 22              5.8   84088
# 23              6.0   86088
# 24              6.4   82363
# 25              6.5   94940
# 26              7.3   92738
# 27              7.6   99273
# 28              8.4  102302
# 29              8.7  114812
# 30              9.2  110431
# 31              9.5  106582
# ...

# %%
data.describe()   #Getting a description of the data
# Out:
#        YearsExperience         Salary
# count        40.000000      40.000000
# mean          6.177500   79325.500000
# std           3.071664   29135.770366
# min           1.600000   38731.000000
# 25%           3.700000   57878.250000
# 50%           5.500000   67983.500000
# 75%           8.825000  107544.250000
# max          11.500000  124873.000000

# %%
data.columns  #shows all the columns in index form
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
data.columns.values
# Out:
# array(['YearsExperience', 'Salary'], dtype=object)

# %%
plt.hist(data)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Showing the Data on Salary and Years of Experience')
plt.show()

# %%
data.shape
# Out:
# (40, 2)

# %%
#Separating data
X = data.iloc[:, :-1]
X
# Out:
#     YearsExperience
# 0               1.6
# 1               1.8
# 2               2.0
# 3               2.5
# 4               2.6
# 5               2.7
# 6               3.0
# 7               3.4
# 8               3.5
# 9               3.7
# 10              3.7
# 11              4.2
# 12              4.4
# 13              4.5
# 14              4.6
# 15              4.7
# 16              4.8
# 17              5.0
# 18              5.2
# 19              5.4
# 20              5.6
# 21              5.7
# 22              5.8
# 23              6.0
# 24              6.4
# 25              6.5
# 26              7.3
# 27              7.6
# 28              8.4
# 29              8.7
# 30              9.2
# 31              9.5
# 32             10.0
# 33             10.1
# 34             10.8
# 35             11.0
# 36             11.1
# 37             11.2
# 38             11.4
# 39             11.5

# %%
X1 = data.loc[:,'YearsExperience']
X1

X1 = data.iloc[:,0]
X1
# Out:
# 0      1.6
# 1      1.8
# 2      2.0
# 3      2.5
# 4      2.6
# 5      2.7
# 6      3.0
# 7      3.4
# 8      3.5
# 9      3.7
# 10     3.7
# 11     4.2
# 12     4.4
# 13     4.5
# 14     4.6
# 15     4.7
# 16     4.8
# 17     5.0
# 18     5.2
# 19     5.4
# 20     5.6
# 21     5.7
# 22     5.8
# 23     6.0
# 24     6.4
# 25     6.5
# 26     7.3
# 27     7.6
# 28     8.4
# 29     8.7
# 30     9.2
# 31     9.5
# 32    10.0
# 33    10.1
# 34    10.8
# 35    11.0
# 36    11.1
# 37    11.2
# 38    11.4
# 39    11.5
# Name: YearsExperience, dtype: float64

# %%
#Separating data
X = data.iloc[:, :-1].values
X
# Out:
# array([[ 1.6],
#        [ 1.8],
#        [ 2. ],
#        [ 2.5],
#        [ 2.6],
#        [ 2.7],
#        [ 3. ],
#        [ 3.4],
#        [ 3.5],
#        [ 3.7],
#        [ 3.7],
#        [ 4.2],
#        [ 4.4],
#        [ 4.5],
#        [ 4.6],
#        [ 4.7],
#        [ 4.8],
#        [ 5. ],
#        [ 5.2],
#        [ 5.4],
#        [ 5.6],
#        [ 5.7],
#        [ 5.8],
#        [ 6. ],
#        [ 6.4],
#        [ 6.5],
#        [ 7.3],
#        [ 7.6],
#        [ 8.4],
#        [ 8.7],
#        [ 9.2],
#        [ 9.5],
#        [10. ],
#        [10.1],
#        [10.8],
#        [11. ],
#        [11.1],
#        [11.2],
#        [11.4],
#        [11.5]])

# %%
X = data.iloc[:, :-1].values
Y = data.iloc[:, 1].values

# %%
#Spliting the data into training and test dataset

from sklearn.model_selection import train_test_split

x_train, x_test,y_train,  y_test = train_test_split(X, Y, test_size=0.20, random_state=0)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (32, 1)
# (8, 1)
# (32,)
# (8,)

# %%
#Building Linear Regression

from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Predicting model

y_pred = model.predict(x_test)

# %%
print(y_pred, y_test)
# Out:
# [75329.65780197 73469.6982986  81839.51606376 45570.30574808
#  55800.0830166  65099.88053345 99509.13134576 60449.98177503] [ 84088  67029  94940  46525  65445  57957 102302  58189]

# %%
#Visualizing the training set

plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, model.predict(x_train), color='blue')
plt.title('Salary Vs YearsExperience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
#Visualizing the testing dataset

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, model.predict(x_train), color='blue')
plt.title('Salary Vs YearsExperience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
np.random.rand()
# Out:
# 0.24512788356159776

# %%
np.random.rand()
# Out:
# 0.7235564630690221

# %%
np.random.rand()
# Out:
# 0.19771733483207343

# %%
np.random.seed(123)  #pseudo random numbers
np.random.rand()
# Out:
# 0.6964691855978616

# %%
np.random.rand()
# Out:
# 0.28613933495037946

# %%
np.random.rand()
# Out:
# 0.2268514535642031

# %%
np.random.rand()
# Out:
# 0.5513147690828912

# %%
np.random.seed(123)
np.random.rand()
# Out:
# 0.6964691855978616

# %%
np.random.rand()
# Out:
# 0.28613933495037946
